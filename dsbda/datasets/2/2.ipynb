# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset_Facebook.csv",sep=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
# CREATE DATA SUBSETS

# %%
df1 = df[["like","comment","Lifetime Post Total Reach"]].loc[0:15]

# %%
df1
# Out:
#       like  comment  Lifetime Post Total Reach
# 0     79.0        4                       2752
# 1    130.0        5                      10460
# 2     66.0        0                       2413
# 3   1572.0       58                      50128
# 4    325.0       19                       7244
# 5    152.0        1                      10472
# 6    249.0        3                      11692
# 7    325.0        0                      13720
# 8    161.0        0                      11844
# 9    113.0        3                       4694
# 10   233.0        0                      21744
# 11    88.0        0                       3112
# 12    90.0        0                       2847
# 13   137.0        5                       2549
# 14   577.0        2                      22784
# 15    86.0        4                      10060

# %%
df2 = df[["like","comment","Lifetime Post Total Reach"]].loc[16:30]

# %%
df2
# Out:
#      like  comment  Lifetime Post Total Reach
# 16   40.0        2                       1722
# 17  678.0       15                      53264
# 18   54.0        4                       3930
# 19   34.0        0                       1591
# 20   66.0        3                       2848
# 21    0.0        0                       1384
# 22   16.0        0                       3454
# 23   72.0        0                       2723
# 24   99.0        3                       8488
# 25   88.0        0                       8284
# 26  412.0       10                      19552
# 27  100.0        0                       2478
# 28  523.0       36                       9560
# 29  143.0       18                      36208
# 30  107.0       33                       4940

# %%
# MERGE DATA

# %%
merge_df = pd.concat([df1,df2])

# %%
merge_df
# Out:
#       like  comment  Lifetime Post Total Reach
# 0     79.0        4                       2752
# 1    130.0        5                      10460
# 2     66.0        0                       2413
# 3   1572.0       58                      50128
# 4    325.0       19                       7244
# 5    152.0        1                      10472
# 6    249.0        3                      11692
# 7    325.0        0                      13720
# 8    161.0        0                      11844
# 9    113.0        3                       4694
# 10   233.0        0                      21744
# 11    88.0        0                       3112
# 12    90.0        0                       2847
# 13   137.0        5                       2549
# 14   577.0        2                      22784
# 15    86.0        4                      10060
# 16    40.0        2                       1722
# 17   678.0       15                      53264
# 18    54.0        4                       3930
# ...

# %%
# SORT DATA

# %%
sort = df.sort_values(["like"],ascending=False)

# %%
sort
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...
